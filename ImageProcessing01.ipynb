# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv.imread(r'D:\Anaconda project\x.tif')
imnot = cv.bitwise_not(img)
A = np.array(img)
B = np.array(imnot)
res1 = np.maximum(A, B)
plt.imshow(img)
plt.show()
plt.close()
plt.imshow(imnot)
plt.show()
plt.close()
plt.imshow(res1)
plt.show()
plt.close()
