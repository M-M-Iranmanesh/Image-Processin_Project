# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
img = cv.imread(r'D:\Anaconda project\test.png')
imnot = cv.bitwise_not(img)
res1 = imnot - img
res2 = img - imnot
plt.imshow(img)
plt.show()
plt.close()
plt.imshow(imnot)
plt.show()
plt.close()
plt.imshow(res1)
plt.show()
plt.close()
plt.imshow(res2)
plt.show()
plt.close()
